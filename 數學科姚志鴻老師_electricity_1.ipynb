# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesookl/MyProject/blob/main/%E6%95%B8%E5%AD%B8%E7%A7%91%E5%A7%9A%E5%BF%97%E9%B4%BB%E8%80%81%E5%B8%AB_electricity_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color = '#b71540'>了解臺灣目前電力狀況 </font>
#
# * **<font color = '#3F0716'>我們將使用 Python 搭配 Pandas 和 Plotly 兩個套件，處理 GitHub 上的一組能源資料 [Data on Energy by Our World in Data](https://github.com/owid/energy-data) ，並視覺化臺灣的電力狀況，以下是逐步指引，幫助你完成這個任務。**
# * **你可以選擇自己撰寫程式碼，也可以試試如何下適當的指令讓 Gemini 幫你生成程式碼</font>**

# %%
print('Hello')
# Out:
# Hello

# %%
# prompt: print hello on screen

print('Hello')

# %% [markdown]
# ##<img src = "https://drive.google.com/uc?id=1_aEeGB5ZNQlkRx7sIHuXYw1mkuSizmE0" height = "50px"><font color = '#4a69bd'> 資料蒐集與清理 </font>

# %% [markdown]
# ###<font color = '#22a6b3'>1. 取得能源資料</font>
# **任務：將桌面上的 owid-energy-data.csv 上傳到你的 Google Drive 中，將資料載入 Colab，並讀取成一個表格 DataFrame。**
#
# ❗<font color = 'CE2B1E'>請不要直接將檔案上傳到 Colab 左方的「檔案」區塊內，否則往後每個禮拜你都要重複以上動作</font>

# %%
import pandas as pd
df = pd.read_csv('https://drive.google.com/uc?id=1d7lU6Di54KSNABFsQcYvXV5pETxntAKz')  # 讀取 CSV 檔案到 DataFrame

# %% [markdown]
# ###<font color = '#22a6b3'>2. 檢查資料是否正確載入</font>
# **任務：試著顯示表格的前5筆資料，看看有沒有成功。**
#
# 此步驟執行後，可顯示結果如下
# ![截圖](data:image/png;base64,...)

# %%
df.head()
#df.head(10)
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %% [markdown]
# ###<font color = '#22a6b3'>3. 了解資料的大小</font>
# **任務：現在你有一堆資料，但它到底有多大呢？總共有幾筆資料？幾個欄位？**

# %%
df.shape
# Out:
# (21812, 130)

# %% [markdown]
# ###<font color = '#22a6b3'>4. 探索資料的欄位</font>
# **任務：列出資料裡所有的欄位名稱，讓我們知道有哪些東西可以分析。**

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=130)

# %% [markdown]
# ###<font color = '#22a6b3'>5. 檢查資料是否有缺漏</font>
# **任務：檢查資料中哪些欄位有缺漏的地方，並試著看看缺漏的情況有多嚴重。**

# %%
df.isna().sum()
# Out:
# country                       0
# year                          0
# iso_code                   5000
# population                 3365
# gdp                       10037
#                           ...
# wind_elec_per_capita      14534
# wind_electricity          13578
# wind_energy_per_capita    17659
# wind_share_elec           14615
# wind_share_energy         17619
# Length: 130, dtype: int64

# %% [markdown]
# ###<font color = '#22a6b3'>6. 挑選特定列的資料</font>
# **任務：取出第1342、6703、5891、5385列的資料，並顯示出來。**

# %% [markdown]
# ###<font color = '#22a6b3'>7. 觀察缺漏的原因</font>
# **任務：看看這些資料，猜猜為什麼iso_code會缺漏。想一想這些列的資料分別是什麼原因導致缺漏？**

# %% [markdown]
# ###<font color = '#22a6b3'>8. 處理缺漏的資料</font>
# **任務：在接下來的課程中，我們會先了解臺灣的電力資料，緊接著會與其他國家的電力互相比較。根據你的觀察，決定怎麼處理這些缺漏。**

# %% [markdown]
# ###<font color = '#22a6b3'>9. 檢查缺漏處理的結果</font>
# **任務：讓電腦隨機挑選10筆資料，看看缺漏的欄位是否都處理好了**

# %% [markdown]
# ###<font color = '#22a6b3'>10. 檢查是否有重複資料</font>
# **任務：檢查資料中是否有「國家與年度」同時重複的情況，如果有，顯示出來**
